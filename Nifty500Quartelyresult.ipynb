# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmesudhanshu/Nifty-500-Quaterly-analysis/blob/main/Nifty500Quartelyresult.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
nifty=pd.read_csv("/content/nifty_500_quarterly_results.csv")

# %%
nifty
# Out:
#                            name    NSE_code BSE_code  \
# 0                 3M India Ltd.     3MINDIA   523395
# 1                      ACC Ltd.         ACC   500410
# 2          AIA Engineering Ltd.      AIAENG   532683
# 3         APL Apollo Tubes Ltd.   APLAPOLLO   533758
# 4    Au Small Finance Bank Ltd.      AUBANK   540611
# ..                          ...         ...      ...
# 496     Allcargo Logistics Ltd.    ALLCARGO   532749
# 497            Sheela Foam Ltd.         SFL   540203
# 498        Alok Industries Ltd.    ALOKINDS   521070
# 499      Minda Corporation Ltd.   MINDACORP   538962
# 500        Concord Biotech Ltd.  CONCORDBIO   543960
#
#                               sector                     industry  revenue  \
# 0                GENERAL INDUSTRIALS         INDUSTRIAL MACHINERY    1,057
# 1            CEMENT AND CONSTRUCTION     CEMENT & CEMENT PRODUCTS  4,644.8
# 2                GENERAL INDUSTRIALS       OTHER INDUSTRIAL GOODS  1,357.1
# ...

# %%
nifty.head()
# Out:
#                          name   NSE_code BSE_code                   sector  \
# 0               3M India Ltd.    3MINDIA   523395      GENERAL INDUSTRIALS
# 1                    ACC Ltd.        ACC   500410  CEMENT AND CONSTRUCTION
# 2        AIA Engineering Ltd.     AIAENG   532683      GENERAL INDUSTRIALS
# 3       APL Apollo Tubes Ltd.  APLAPOLLO   533758          METALS & MINING
# 4  Au Small Finance Bank Ltd.     AUBANK   540611      BANKING AND FINANCE
#
#                    industry  revenue operating_expenses operating_profit  \
# 0      INDUSTRIAL MACHINERY    1,057              847.4            192.1
# 1  CEMENT & CEMENT PRODUCTS  4,644.8            3,885.4            549.3
# 2    OTHER INDUSTRIAL GOODS  1,357.1              912.7            382.1
# 3     IRON & STEEL PRODUCTS    4,650            4,305.4              325
# 4                     BANKS  2,956.5            1,026.7            647.7
#
#   operating_profit_margin depreciation interest profit_before_tax    tax  \
# ...

# %%
nifty.tail()
# Out:
#                         name    NSE_code BSE_code  \
# 496  Allcargo Logistics Ltd.    ALLCARGO   532749
# 497         Sheela Foam Ltd.         SFL   540203
# 498     Alok Industries Ltd.    ALOKINDS   521070
# 499   Minda Corporation Ltd.   MINDACORP   538962
# 500     Concord Biotech Ltd.  CONCORDBIO   543960
#
#                               sector                     industry  revenue  \
# 496                   TRANSPORTATION   TRANSPORTATION - LOGISTICS  3,336.3
# 497    DIVERSIFIED CONSUMER SERVICES  FURNITURE-FURNISHING-PAINTS    637.6
# 498  TEXTILES APPARELS & ACCESSORIES                     TEXTILES  1,369.3
# 499    AUTOMOBILES & AUTO COMPONENTS       AUTO PARTS & EQUIPMENT  1,197.9
# 500  PHARMACEUTICALS & BIOTECHNOLOGY                BIOTECHNOLOGY    270.5
#
#     operating_expenses operating_profit operating_profit_margin depreciation  \
# 496            3,188.8              118                   3.57%        106.7
# ...

# %%
nifty.sample(5)
# Out:
#                        name    NSE_code BSE_code  \
# 340          Birlasoft Ltd.       BSOFT   532400
# 21        Avanti Feeds Ltd.  AVANTIFEED   512573
# 401      Indigo Paints Ltd.  INDIGOPNTS   543258
# 236  TVS Motor Company Ltd.    TVSMOTOR   532343
# 106               HFCL Ltd.        HFCL   500183
#
#                             sector                     industry  revenue  \
# 340            SOFTWARE & SERVICES     IT CONSULTING & SOFTWARE  1,325.4
# 21        FOOD BEVERAGES & TOBACCO          OTHER FOOD PRODUCTS    1,312
# 401  DIVERSIFIED CONSUMER SERVICES  FURNITURE-FURNISHING-PAINTS    273.4
# 236  AUTOMOBILES & AUTO COMPONENTS                 2/3 WHEELERS  9,983.8
# 106   TELECOMMUNICATIONS EQUIPMENT               TELECOM CABLES  1,128.7
#
#     operating_expenses operating_profit operating_profit_margin depreciation  \
# 340            1,102.7            207.1                  15.81%         21.5
# ...

# %%
nifty.describe()
# Out:
#                EPS      EPS_TTM
# count   500.000000   498.000000
# mean     15.252400    54.043775
# std      66.113983   193.529196
# min     -32.400000  -214.800000
# 25%       2.100000     8.900000
# 50%       5.350000    22.400000
# 75%      14.200000    52.675000
# max    1383.300000  3988.000000

# %%
nifty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     501 non-null    object
#  1   NSE_code                 501 non-null    object
#  2   BSE_code                 501 non-null    object
#  3   sector                   501 non-null    object
#  4   industry                 501 non-null    object
#  5   revenue                  500 non-null    object
#  6   operating_expenses       500 non-null    object
#  7   operating_profit         500 non-null    object
#  8   operating_profit_margin  500 non-null    object
#  9   depreciation             500 non-null    object
#  10  interest                 500 non-null    object
#  11  profit_before_tax        500 non-null    object
#  12  tax                      500 non-null    object
#  13  net_profit               500 non-null    object
# ...

# %%
nifty.isnull().sum()
# Out:
# name                       0
# NSE_code                   0
# BSE_code                   0
# sector                     0
# industry                   0
# revenue                    1
# operating_expenses         1
# operating_profit           1
# operating_profit_margin    1
# depreciation               1
# interest                   1
# profit_before_tax          1
# tax                        1
# net_profit                 1
# EPS                        1
# profit_TTM                 3
# EPS_TTM                    3
# dtype: int64

# %%
nifty.duplicated().sum()
# Out:
# 0

# %%
nifty.dropna(subset=["operating_expenses"],inplace=True)

# %%
nifty['operating_expenses'] = nifty['operating_expenses'].str.replace(',', '')

# %%
nifty["operating_expenses"]=nifty["operating_expenses"].astype(float)

# %%
nifty["operating_expenses"].mean()
# Out:
# 5488.1676

# %%
nifty["sector"].value_counts().plot(kind="pie",figsize=(20,20),autopct="%1.1f%%", textprops={"fontsize":20})
# Out:
# <Axes: ylabel='count'>

# %%
nifty.columns
# Out:
# Index(['name', 'NSE_code', 'BSE_code', 'sector', 'industry', 'revenue',
#        'operating_expenses', 'operating_profit', 'operating_profit_margin',
#        'depreciation', 'interest', 'profit_before_tax', 'tax', 'net_profit',
#        'EPS', 'profit_TTM', 'EPS_TTM'],
#       dtype='object')

# %%
nifty.values
#all the value of rows will come in 2 D array
# Out:
# array([['3M India Ltd.', '3MINDIA', '523395', ..., 129.7, '535.9', 475.7],
#        ['ACC Ltd.', 'ACC', '500410', ..., 20.7, '1,202.7', 64.0],
#        ['AIA Engineering Ltd.', 'AIAENG', '532683', ..., 34.3, '1,216.1',
#         128.9],
#        ...,
#        ['Alok Industries Ltd.', 'ALOKINDS', '521070', ..., -0.3,
#         '-948.4', -1.9],
#        ['Minda Corporation Ltd.', 'MINDACORP', '538962', ..., 2.5,
#         '278.2', 11.6],
#        ['Concord Biotech Ltd.', 'CONCORDBIO', '543960', ..., 7.7, nan,
#         nan]], dtype=object)

# %%
#Drop_duplicate
nifty.duplicated().sum()
# Out:
# 0

# %%
nifty.drop_duplicates(inplace=True)

# %%
nifty
# Out:
#                            name    NSE_code BSE_code  \
# 0                 3M India Ltd.     3MINDIA   523395
# 1                      ACC Ltd.         ACC   500410
# 2          AIA Engineering Ltd.      AIAENG   532683
# 3         APL Apollo Tubes Ltd.   APLAPOLLO   533758
# 4    Au Small Finance Bank Ltd.      AUBANK   540611
# ..                          ...         ...      ...
# 496     Allcargo Logistics Ltd.    ALLCARGO   532749
# 497            Sheela Foam Ltd.         SFL   540203
# 498        Alok Industries Ltd.    ALOKINDS   521070
# 499      Minda Corporation Ltd.   MINDACORP   538962
# 500        Concord Biotech Ltd.  CONCORDBIO   543960
#
#                               sector                     industry  revenue  \
# 0                GENERAL INDUSTRIALS         INDUSTRIAL MACHINERY    1,057
# 1            CEMENT AND CONSTRUCTION     CEMENT & CEMENT PRODUCTS  4,644.8
# 2                GENERAL INDUSTRIALS       OTHER INDUSTRIAL GOODS  1,357.1
# ...

# %%
industry=nifty.groupby("industry")

# %%
industry.mean("operating_expenses")
# Out:
#                                   operating_expenses        EPS     EPS_TTM
# industry
# 2/3 WHEELERS                             7121.475000  41.725000  141.450000
# AGROCHEMICALS                            1991.942857  12.371429   51.657143
# AIRLINES                                12743.600000   4.900000  145.700000
# ALUMINIUM AND ALUMINIUM PRODUCTS        26223.300000   2.033333   19.600000
# ASSET MANAGEMENT COS.                     163.533333  12.900000   45.366667
# ...                                              ...        ...         ...
# TRANSPORTATION - LOGISTICS               2082.633333  10.100000   43.466667
# TRAVEL SUPPORT SERVICES                   474.900000   2.800000    9.900000
# UTILITIES                                6877.433333   9.983333   33.400000
# WAREHOUSING AND LOGISTICS                1648.400000   6.000000   19.500000
# ZINC                                     3652.000000   4.100000   20.000000
#
# [97 rows x 3 columns]
